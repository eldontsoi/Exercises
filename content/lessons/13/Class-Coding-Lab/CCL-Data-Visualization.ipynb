# %% [markdown]
# # In-Class Coding Lab: Data Visualization
#
# The goals of this lab are to help you understand:
#
#  - The value of visualization: A picture is worth 1,000 words!
#  - The various ways to visualize information
#  - The basic requirements for any visualization
#  - How to plot complex visualizations such as multi-series charts and maps
#  - Visualization Tools:
#      - Matplolib
#      - Plot.ly
#      - Folium Maps

# %%
# %matplotlib inline 

import matplotlib
import matplotlib.pyplot as plt
import plotly 
import plotly.plotly as py     
import plotly.graph_objs as go  
import cufflinks as cf
import pandas as pd
import folium
import warnings
#matplotlib.rcParams['figure.figsize'] = (20.0, 10.0) # larger figure size
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Back to the movie goers data set
#
# For this lab, we will once again use the movie goers dataset. As you may recall this data set is a survey demographic survey of people who go to the movies. Let's reload the data and setup our `age_group` feature again.

# %%
goers = pd.read_csv('CCL-moviegoers.csv')
goers['age_group'] = ''
goers['age_group'][goers['age'] <=18] = 'Youth'
goers['age_group'][(goers['age'] >=19) & (goers['age'] <=55)] = 'Adult'
goers['age_group'][goers['age'] >=56] = 'Senior'

goers.sample(5)
# Out:
#      user_id  age gender occupation zip_code age_group
# 491      492   57      M   educator    94618    Senior
# 503      504   40      F     writer    92115     Adult
# 258      259   21      M    student    48823     Adult
# 197      198   21      F    student    55414     Adult
# 553      554   32      M  scientist    62901     Adult

# %% [markdown]
# ## Visualizing Data
#
# There are many ways your can visualize information. Which one is the most appropriate? It depends on the data, of course.
#
# - **Counting Categorial data** belongs in *charts like pie charts and bar charts*.
# - **Counting Numerical data** is best suited for *histograms*.
# - **Timeseries data and continuous data** belongs in *line charts*.
# - **A comparision of two continuous values** is best suited for a *scatter plot*.
# - **Geographical data** is best displauyed on *maps*.
#
# Let's use this knowledge to plot some data in the `goers` `DataFrame`!
#
# ## Males or Females?
#
# The first think we might want to visualize is a count gender in the dataset. A **pie** chart is well suited for this task as it displays data as a portion of a whole. To create a pie chart we need the data to count and the labels for the counts.
#
# Let's try it.
#
# First we get the value counts as a series `gender`:

# %%
gender = goers['gender'].value_counts()
gender
# Out:
# M    670
# F    273
# Name: gender, dtype: int64

# %% [markdown]
# Then we make it into a dataframe:

# %%
gender_df = pd.DataFrame( { 'Gender' : gender.index,  "Counts" : gender })
gender_df
# Out:
#    Counts Gender
# M     670      M
# F     273      F

# %% [markdown]
# Then we plot! The index has the labels, and the value at the index is what we want to plot:

# %%
gender_df.plot.pie( y = 'Counts') # y are the values we are plotting

# %% [markdown]
# ### Now You Try it!
#
# Create a pie chart based on `age_group` first create a series of the `value_counts()` second, create the `DataFrame` with two columns `AgeGroup` and `Counts` then plot with `.plot.pie()`.
#
# Follow the steps we did in the previous three cells, but comvine into one cell!

# %%
#todo write code here
age = goers['age'].value_counts()
#age.sample(3)
age_group = pd.DataFrame( { 'age' : age.index,  "Counts" : age })
#age_group.sample(3)
age_group.plot.pie(y = 'Counts') # y are the values we are plotting

# %%
age = goers['age'].value_counts()
age.sample(3)
# Out:
# 53    12
# 62     2
# 48    20
# Name: age, dtype: int64

# %%
age_group = pd.DataFrame( { 'age' : age.index,  "Counts" : age })
age_group.sample(3)
# Out:
#     Counts  age
# 30      39   30
# 15       6   15
# 60       9   60

# %% [markdown]
# ## Too many pieces of the pie?
#
# Pie charts are nice, but they are only useful when you have a small number of labels. More that 5-7 labels and the pie becomes messy. For example take a look at this pie chart of `occupation`:

# %%
occ = goers['occupation'].value_counts()
occ_df = pd.DataFrame( { 'occupation' : occ.index,  "counts" : occ })
occ_df.plot.pie(y = 'counts')

# %% [markdown]
# That's crazy... and difficult to comprehend. Also pie charts visualize data as part of the whole. We have no idea how many students there are. Sometimes we want to know actual counts. This is where the **bar chart** comes in handy!
#
# ## Raising the bar!
#
# Let's reproduce the same plot as a bar:

# %%
occ_df.plot.bar()

# %% [markdown]
# Ahh. that's much better. So much easier to understand!
#
# ### Now you try it!
#
# Write a one-liner to plot `groups_df` as a Bar!

# %%
# todo write code here
age_group.plot.bar()

# %% [markdown]
# ## When bar charts fail...
#
# Bar charts have the same problem as pie charts. Too many categories overcomplicate the chart, or show the data in a meaningless way. For example, let's create a bart chart for ages:

# %%
ages = goers['age'].value_counts()
ages_df = pd.DataFrame( { 'age' : ages.index,  "counts" : ages })
ages_df.plot.bar(y = 'counts')

# %% [markdown]
# Meaningless. For two key reasons:
#
# 1. too many categories
# 2. age is a continuous variable not a categorical variable. In plain English, this means there's a relationship between one age and the next.  20 < 21 < 22. This is not represented in a bar chart.
#
# ## ...Call in the Histogram!
#
# What we want is a **historgram**, which takes a continuous variable and loads counts into "buckets".  Notice how we didn't have to lump data with `value_counts()`. Histograms can do that automatically because the `age` variable is continuous. Let's try it:

# %%
goers.hist(column ='age')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x114a494a8>]],
#       dtype=object)

# %% [markdown]
# ## Plot.ly
#
# [Plot.ly](https://plot.ly) is data visualization as a service. You give it data, it gives you back a web-based plot. Plot.ly is free and works with a variety of environments and programming languages, including Python.
#
# For Python is has bindings so that you can use it just like `matplotlib`! No need to manually invoke the web service call.
#
# To get started with plot.ly you must sign up for an account and get a set of credentials:
#
# - Visit [https://plot.ly/settings/api](https://plot.ly/settings/api)
# - Create an account or sign-in with Google or GitHub
# - Generate your API key and paste your username and key in the code below:

# %%
# todo: setup the credentials replace ??? and ??? with your Plot.ly username and api_key
plotly.tools.set_credentials_file(username='EldonTsoi', api_key='EoEyhwiqRMbQP66DZWgg')

# %% [markdown]
# Using plot.ly is as easy as, or sometimes easier than `matplotlib`. In most cases all you need to do is call `iplot()` on the data frame. For example, here's out first pie chart, plotly style:

# %%
gender_df.iplot(kind="pie", labels = 'Gender', values='Counts')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~EldonTsoi/8.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# Notice that plot.ly is a bit more interactive. You can hover over the part of the pie chart and see counts!
#
# ### Now You Try it!
#
# Use plotly's `iplot()` method to create a bar chart on the `occ_df` Data Frame:

# %%
# todo: write code here
occ_df.iplot()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~EldonTsoi/10.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Folium with Leaflet.js
#
# Folium is a Python module wrapper for [Leaflet.js](http://leafletjs.com/), which uses [Open Street Maps](https://www.openstreetmap.us/). These are two, popular open source mapping libraries. Unlike Google maps API, its 100% free!
#
# You can use Folium to render maps in Python and put data on the maps. Here's how easy it is to bring up a map:

# %%
CENTER_US = (22,114)
london = (51.5074, -0.1278)
map = folium.Map(location=CENTER_US, zoom_start=14)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# You can zoom right down to the street level and get a amazing detail. There's also different maps you can use, as was covered in this week's reading.
#
# ## Mapping the students.
#
# Let's take the largest category of movie goers and map their whereabouts. We will first need to import a data set to give us a lat/lng for the `zip_code` we have in the dataframe. We could look this up with Google's geolookup API, but that's too slow as we will be making 100's of requests. It's better to have them stored already and merge them with `goers`!
#
# Let's import the zipcode database into a Pandas DataFrame, then merge it with the `goers` DataFrame:

# %%
zipcodes = pd.read_csv('https://raw.githubusercontent.com/mafudge/datasets/master/zipcodes/free-zipcode-database-Primary.csv', dtype = {'Zipcode' :object})
data = goers.merge(zipcodes,  how ='inner', left_on='zip_code', right_on='Zipcode')
students = data[ data['occupation'] == 'student']
students.sample(3)
# Out:
#      user_id  age gender occupation zip_code age_group Zipcode ZipCodeType  \
# 713      774   30      M    student    80027     Adult   80027    STANDARD
# 405      880   13      M    student    83702     Youth   83702    STANDARD
# 805      917   22      F    student    20006     Adult   20006    STANDARD
#
#            City State LocationType    Lat    Long             Location  \
# 713  LOUISVILLE    CO      PRIMARY  39.96 -105.14  NA-US-CO-LOUISVILLE
# 405       BOISE    ID      PRIMARY  43.71 -116.18       NA-US-ID-BOISE
# 805  WASHINGTON    DC      PRIMARY  38.89  -77.03  NA-US-DC-WASHINGTON
#
#      Decommisioned  TaxReturnsFiled  EstimatedPopulation   TotalWages
# 713          False          14983.0              27059.0  959161213.0
# 405          False          10516.0              16631.0  494886330.0
# 805          False            826.0               1044.0   41161797.0

# %% [markdown]
# Let's explain the code, as a Pandas refresher course:
#
# 1. in the first line I added `dtype = {'Zipcode' :object}` to force the `Zipcode` column to be of type `object` without that, it imports as type `int` and cannot match with the `goers` DataFrame.
# 1. the next line merges the two dataframes together where the `zip_code` in `doers` (on_left) matches `Zipcode` in `zipcodes` (on_right)
# 1. the result `data` is a combined DataFrame, which we then filter to only `student` occupations, sorting that in the `students` DataFrame
#
#
# ## Slapping those students on a map!
#
# We're ready to place the students on a map. It's easy:
#
# 1. For each row in the students dataframe:
# 1.   get the coordinates (lat /lng )
# 1.   make a `marker` with the coordinates
# 1.   add the marker to the map with `add_children()`
#
# Here we go!

# %%
for row in students.to_records():
    pos = (row['Lat'],row['Long'])
    message = "%d year old %s  from %s, %s" % (row['age'],row['gender'], row['City'], row['State'])
    marker = folium.Marker(location=pos, 
                    popup=message
                          )
    map.add_children(marker)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Now you try it!
#
#
# 1. use the `data` DataFrame to retrieve only the occupation `programmer`
# 1. create another map `map2` plot the programmers on that map!

# %%
## todo write code here!
students = data[ data['occupation'] == 'programmer']
students
# Out:
#      user_id  age gender  occupation zip_code age_group Zipcode ZipCodeType  \
# 3         29   41      M  programmer    94043     Adult   94043    STANDARD
# 15       300   26      F  programmer    55106     Adult   55106    STANDARD
# 49       352   37      F  programmer    55105     Adult   55105    STANDARD
# 50       421   38      F  programmer    55105     Adult   55105    STANDARD
# 64        45   29      M  programmer    50233     Adult   50233    STANDARD
# 70        53   26      M  programmer    55414     Adult   55414    STANDARD
# 75       551   25      M  programmer    55414     Adult   55414    STANDARD
# 76       633   35      M  programmer    55414     Adult   55414    STANDARD
# 80        58   27      M  programmer    52246     Adult   52246    STANDARD
# 93       800   25      M  programmer    55337     Adult   55337    STANDARD
# 106       82   50      M  programmer    22902     Adult   22902    STANDARD
# 125      102   38      M  programmer    30220     Adult   30220    STANDARD
# 128      404   29      F  programmer    55108     Adult   55108    STANDARD
# 137      114   27      M  programmer    75013     Adult   75013    STANDARD
# 143      119   32      M  programmer    67401     Adult   67401    STANDARD
# 161      134   31      M  programmer    80236     Adult   80236    STANDARD
# 166      645   27      M  programmer    53211     Adult   53211    STANDARD
# 168      141   49      M  programmer    36117     Adult   36117    STANDARD
# 169      144   53      M  programmer    20910     Adult   20910    STANDARD
# 187      263   41      M  programmer    55346     Adult   55346    STANDARD
# 188      160   27      M  programmer    66215     Adult   66215    STANDARD
# 209      177   20      M  programmer    19104     Adult   19104    STANDARD
# 215      182   36      M  programmer    33884     Adult   33884    STANDARD
# 231      200   40      M  programmer    93402     Adult   93402    STANDARD
# 247      215   35      M  programmer    63033     Adult   63033    STANDARD
# 249      219   32      M  programmer    43212     Adult   43212    STANDARD
# 253      222   29      M  programmer    27502     Adult   27502    STANDARD
# 308      279   33      M  programmer    85251     Adult   85251    STANDARD
# 310      283   28      M  programmer    55305     Adult   55305    STANDARD
# 313      285   25      M  programmer    53713     Adult   53713    STANDARD
# 320      292   35      F  programmer    94703     Adult   94703    STANDARD
# 333      305   23      M  programmer    94086     Adult   94086    STANDARD
# 349      319   38      M  programmer    22030     Adult   22030    STANDARD
# 395      379   44      M  programmer    98117     Adult   98117    STANDARD
# 399      384   52      M  programmer    45218     Adult   45218    STANDARD
# 429      414   24      M  programmer    38115     Adult   38115    STANDARD
# 432      658   33      M  programmer    92626     Adult   92626    STANDARD
# 457      470   24      M  programmer    10021     Adult   10021    STANDARD
# 481      475   30      M  programmer    75230     Adult   75230    STANDARD
# 505      499   42      M  programmer    75006     Adult   75006    STANDARD
# 519      514   27      M  programmer    20707     Adult   20707    STANDARD
# 582      595   25      M  programmer    31909     Adult   31909    STANDARD
# 588      603   21      M  programmer    47905     Adult   47905    STANDARD
# 591      606   28      M  programmer    63044     Adult   63044    STANDARD
# 603      622   25      M  programmer    14850     Adult   14850    STANDARD
# 605      625   27      M  programmer    20723     Adult   20723    STANDARD
# 628      661   28      M  programmer    98121     Adult   98121    STANDARD
# 641      676   30      M  programmer    32712     Adult   32712    STANDARD
# 647      682   23      M  programmer    55128     Adult   55128    STANDARD
# 689      737   30      M  programmer    98072     Adult   98072    STANDARD
# 694      743   31      M  programmer    92660     Adult   92660    STANDARD
# 715      780   49      M  programmer    94560     Adult   94560    STANDARD
# 724      792   40      M  programmer    12205     Adult   12205    STANDARD
# 750      830   46      M  programmer    53066     Adult   53066    STANDARD
# 770      864   27      M  programmer    63021     Adult   63021    STANDARD
# 773      868   21      M  programmer    55303     Adult   55303    STANDARD
# 811      927   23      M  programmer    55428     Adult   55428    STANDARD
#
#                 City State LocationType    Lat    Long  \
# 3      MOUNTAIN VIEW    CA      PRIMARY  37.41 -122.05
# 15        SAINT PAUL    MN      PRIMARY  44.94  -93.10
# 49        SAINT PAUL    MN      PRIMARY  44.94  -93.10
# 50        SAINT PAUL    MN      PRIMARY  44.94  -93.10
# 64          REDFIELD    IA      PRIMARY  41.59  -94.19
# 70       MINNEAPOLIS    MN      PRIMARY  44.96  -93.26
# 75       MINNEAPOLIS    MN      PRIMARY  44.96  -93.26
# 76       MINNEAPOLIS    MN      PRIMARY  44.96  -93.26
# 80         IOWA CITY    IA      PRIMARY  41.65  -91.53
# 93        BURNSVILLE    MN      PRIMARY  44.76  -93.27
# 106  CHARLOTTESVILLE    VA      PRIMARY  38.03  -78.48
# 125       GRANTVILLE    GA      PRIMARY  33.23  -84.82
# 128       SAINT PAUL    MN      PRIMARY  44.94  -93.10
# 137            ALLEN    TX      PRIMARY  33.10  -96.66
# 143           SALINA    KS      PRIMARY  38.81  -97.61
# 161           DENVER    CO      PRIMARY  39.76 -104.87
# 166        MILWAUKEE    WI      PRIMARY  43.06  -87.96
# 168       MONTGOMERY    AL      PRIMARY  32.35  -86.28
# 169    SILVER SPRING    MD      PRIMARY  39.01  -77.02
# 187     EDEN PRAIRIE    MN      PRIMARY  44.84  -93.45
# 188           LENEXA    KS      PRIMARY  38.90  -94.68
# 209     PHILADELPHIA    PA      PRIMARY  39.95  -75.16
# 215     WINTER HAVEN    FL      PRIMARY  28.04  -81.72
# 231         LOS OSOS    CA      PRIMARY  35.29 -120.81
# 247       FLORISSANT    MO      PRIMARY  38.79  -90.32
# 249         COLUMBUS    OH      PRIMARY  39.98  -82.98
# 253             APEX    NC      PRIMARY  35.72  -78.84
# 308       SCOTTSDALE    AZ      PRIMARY  33.49 -111.92
# 310          HOPKINS    MN      PRIMARY  44.92  -93.40
# 313          MADISON    WI      PRIMARY  43.07  -89.38
# 320         BERKELEY    CA      PRIMARY  37.86 -122.27
# 333        SUNNYVALE    CA      PRIMARY  37.36 -122.02
# 349          FAIRFAX    VA      PRIMARY  38.85  -77.29
# 395          SEATTLE    WA      PRIMARY  47.68 -122.38
# 399       CINCINNATI    OH      PRIMARY  39.09  -84.51
# 429          MEMPHIS    TN      PRIMARY  35.10  -90.00
# 432       COSTA MESA    CA      PRIMARY  33.67 -117.90
# 457         NEW YORK    NY      PRIMARY  40.77  -73.95
# 481           DALLAS    TX      PRIMARY  32.79  -96.76
# 505       CARROLLTON    TX      PRIMARY  32.98  -96.89
# 519           LAUREL    MD      PRIMARY  39.09  -76.85
# 582         COLUMBUS    GA      PRIMARY  32.51  -84.87
# 588        LAFAYETTE    IN      PRIMARY  40.41  -86.87
# 591        BRIDGETON    MO      PRIMARY  38.76  -90.42
# 603           ITHACA    NY      PRIMARY  42.44  -76.50
# 605           LAUREL    MD      PRIMARY  39.09  -76.85
# 628          SEATTLE    WA      PRIMARY  47.61 -122.34
# 641           APOPKA    FL      PRIMARY  28.68  -81.51
# 647       SAINT PAUL    MN      PRIMARY  44.94  -93.10
# 689      WOODINVILLE    WA      PRIMARY  47.75 -122.09
# 694    NEWPORT BEACH    CA      PRIMARY  33.62 -117.87
# 715           NEWARK    CA      PRIMARY  37.51 -122.04
# 724           ALBANY    NY      PRIMARY  42.66  -73.79
# 750       OCONOMOWOC    WI      PRIMARY  43.10  -88.49
# 770          BALLWIN    MO      PRIMARY  38.59  -90.55
# 773            ANOKA    MN      PRIMARY  45.21  -93.39
# 811      MINNEAPOLIS    MN      PRIMARY  44.96  -93.26
#
#                      Location  Decommisioned  TaxReturnsFiled  \
# 3      NA-US-CA-MOUNTAIN VIEW          False          14062.0
# 15        NA-US-MN-SAINT PAUL          False          21868.0
# 49        NA-US-MN-SAINT PAUL          False          13220.0
# 50        NA-US-MN-SAINT PAUL          False          13220.0
# 64          NA-US-IA-REDFIELD          False            633.0
# 70       NA-US-MN-MINNEAPOLIS          False           8123.0
# 75       NA-US-MN-MINNEAPOLIS          False           8123.0
# 76       NA-US-MN-MINNEAPOLIS          False           8123.0
# 80         NA-US-IA-IOWA CITY          False           9544.0
# 93        NA-US-MN-BURNSVILLE          False          22600.0
# 106  NA-US-VA-CHARLOTTESVILLE          False          10130.0
# 125       NA-US-GA-GRANTVILLE          False           2133.0
# 128       NA-US-MN-SAINT PAUL          False           7064.0
# 137            NA-US-TX-ALLEN          False          12304.0
# 143           NA-US-KS-SALINA          False          24778.0
# 161           NA-US-CO-DENVER          False           6910.0
# 166        NA-US-WI-MILWAUKEE          False          15202.0
# 168       NA-US-AL-MONTGOMERY          False          21507.0
# 169    NA-US-MD-SILVER SPRING          False          20077.0
# 187     NA-US-MN-EDEN PRAIRIE          False           8543.0
# 188           NA-US-KS-LENEXA          False          12881.0
# 209     NA-US-PA-PHILADELPHIA          False          13589.0
# 215     NA-US-FL-WINTER HAVEN          False          13117.0
# 231         NA-US-CA-LOS OSOS          False           6682.0
# 247       NA-US-MO-FLORISSANT          False          21268.0
# 249         NA-US-OH-COLUMBUS          False          10619.0
# 253             NA-US-NC-APEX          False          13278.0
# 308       NA-US-AZ-SCOTTSDALE          False          17633.0
# 310          NA-US-MN-HOPKINS          False          10962.0
# 313          NA-US-WI-MADISON          False          10745.0
# 320         NA-US-CA-BERKELEY          False           9362.0
# 333        NA-US-CA-SUNNYVALE          False          21695.0
# 349          NA-US-VA-FAIRFAX          False          23677.0
# 395          NA-US-WA-SEATTLE          False          16764.0
# 399       NA-US-OH-CINCINNATI          False           2074.0
# 429          NA-US-TN-MEMPHIS          False          18110.0
# 432       NA-US-CA-COSTA MESA          False          22895.0
# 457         NA-US-NY-NEW YORK          False          29820.0
# 481           NA-US-TX-DALLAS          False          13292.0
# 505       NA-US-TX-CARROLLTON          False          21901.0
# 519           NA-US-MD-LAUREL          False          16142.0
# 582         NA-US-GA-COLUMBUS          False          15634.0
# 588        NA-US-IN-LAFAYETTE          False          18781.0
# 591        NA-US-MO-BRIDGETON          False           5456.0
# 603           NA-US-NY-ITHACA          False          23629.0
# 605           NA-US-MD-LAUREL          False          13172.0
# 628          NA-US-WA-SEATTLE          False           7197.0
# 641           NA-US-FL-APOPKA          False          17644.0
# 647       NA-US-MN-SAINT PAUL          False          14693.0
# 689      NA-US-WA-WOODINVILLE          False          11955.0
# 694    NA-US-CA-NEWPORT BEACH          False          17493.0
# 715           NA-US-CA-NEWARK          False          19485.0
# 724           NA-US-NY-ALBANY          False          14839.0
# 750       NA-US-WI-OCONOMOWOC          False          16563.0
# 770          NA-US-MO-BALLWIN          False          27874.0
# 773            NA-US-MN-ANOKA          False          21908.0
# 811      NA-US-MN-MINNEAPOLIS          False          14155.0
#
#      EstimatedPopulation    TotalWages
# 3                22824.0  1.083207e+09
# 15               36448.0  6.356612e+08
# 49               21132.0  8.058799e+08
# 50               21132.0  8.058799e+08
# 64                1123.0  1.969025e+07
# 70               10417.0  2.547798e+08
# 75               10417.0  2.547798e+08
# 76               10417.0  2.547798e+08
# 80               14879.0  4.039449e+08
# 93               38193.0  9.977815e+08
# 106              16159.0  4.063004e+08
# 125               4046.0  6.803946e+07
# 128              11086.0  3.055841e+08
# 137              25569.0  1.164803e+09
# 143              42461.0  7.874657e+08
# 161              11942.0  2.266265e+08
# 166              22723.0  8.612561e+08
# 168              37488.0  1.036667e+09
# 169              30661.0  1.164742e+09
# 187              15754.0  6.038154e+08
# 188              21795.0  5.765858e+08
# 209              19073.0  3.337392e+08
# 215              23252.0  5.049636e+08
# 231              11297.0  2.198252e+08
# 247              35384.0  6.820263e+08
# 249              14682.0  4.612092e+08
# 253              26612.0  8.645068e+08
# 308              25419.0  6.935941e+08
# 310              17425.0  6.822796e+08
# 313              17493.0  3.067788e+08
# 320              13904.0  3.893109e+08
# 333              37637.0  1.544674e+09
# 349              40608.0  1.557761e+09
# 395              27190.0  9.525196e+08
# 399               3405.0  7.092517e+07
# 429              30519.0  4.307039e+08
# 432              37365.0  1.078903e+09
# 457              42627.0  1.022025e+09
# 481              22222.0  1.403534e+09
# 505              38972.0  8.332862e+08
# 519              26214.0  7.632433e+08
# 582              27967.0  5.962041e+08
# 588              32618.0  7.023996e+08
# 591               9095.0  1.927884e+08
# 603              37136.0  9.661852e+08
# 605              24130.0  8.579026e+08
# 628               8766.0  5.196867e+08
# 641              32901.0  7.947473e+08
# 647              24584.0  6.163715e+08
# 689              21605.0  8.461021e+08
# 694              28529.0  1.587500e+09
# 715              35570.0  9.959243e+08
# 724              23888.0  5.374866e+08
# 750              30069.0  9.258536e+08
# 770              50402.0  1.651342e+09
# 773              39074.0  9.885775e+08
# 811              23451.0  4.915491e+08

# %%
for row in students.to_records():
    pos = (row['Lat'],row['Long'])
    message = "%d year old %s  from %s, %s" % (row['age'],row['gender'], row['City'], row['State'])
    marker = folium.Marker(location=pos, 
                    popup=message
                          )
    map.add_children(marker)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
