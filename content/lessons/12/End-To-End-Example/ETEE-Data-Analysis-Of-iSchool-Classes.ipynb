# %% [markdown]
# # End-To-End Example: Data Analysis of iSchool Classes
#
# In this end-to-end example we will perform a data analysis in Python Pandas we will attempt to answer the following questions:
#
# - What percentage of the schedule are undergrad (course number 500 or lower)?
# - What undergrad classes are on Friday? or at 8AM?
#
# Things we will demonstrate:
#
# - `read_html()` for basic web scraping
# - dealing with 5 pages of data
# - `append()` multiple `DataFrames` together
# - Feature engineering (adding a column to the `DataFrame`)
#
# The iSchool schedule of classes can be found here: https://ischool.syr.edu/classes

# %%
import pandas as pd

# this turns off warning messages
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.DataFrame({
...     'col1' : ['A', 'A', 'B', np.nan, 'D', 'C'],
...     'col2' : [2, 1, 9, 8, 7, 4],
...     'col3': [0, 1, 9, 4, 2, 3],
# Out:
#   File "<ipython-input-3-e5af70222750>", line 4
#     'col3': [0, 1, 9, 4, 2, 3],
#                                ^
# SyntaxError: unexpected EOF while parsing

# %%
classes = pd.DataFrame()
classes.sort_values(by=['Course'])
for num in range(1,6):
    website = 'https://ischool.syr.edu/classes/fall-2018/?page='+str(num)
    datalist = pd.read_html(website)
    classes = classes.append(datalist [0])
    #|website = 'https://ischool.syr.edu/classes/fall-2018/?page=2'
    datalist = pd.read_html(website)
    classes = classes.append(datalist [0])
classes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Course'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-c0266a18742b> in <module>()
#       1 classes = pd.DataFrame()
# ----> 2 classes.sort_values(by=['Course'])
#       3 for num in range(1,6):
#       4     website = 'https://ischool.syr.edu/classes/fall-2018/?page='+str(num)
#       5     datalist = pd.read_html(website)
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3617
#    3618             by = by[0]
# -> 3619             k = self.xs(by, axis=other_axis).values
#    3620             if k.ndim == 2:
#    3621
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    2333
#    2334         if axis == 1:
# -> 2335             return self[key]
#    2336
#    2337         self._consolidate_inplace()
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Course'

# %%
def get_classes_from_website():
    classes = pd.DataFrame()
    for num in range(0,6):
        website = 'https://ischool.syr.edu/classes/fall-2018/?page='+str(num)
        datalist = pd.read_html(website)
        classes = classes.append(datalist[0])
    return classes

# %%
classes = get_classes_from_website()
classes.sample(5)
# Out:
#     Course Section  Class  Credits                           Title  \
# 26  IST195    M008  16913      3.0   LAB: Information Technologies
# 49  IST735    M800  21320      3.0  Copyright for Information Prof
# 35  IST615    M001  21338      3.0                Cloud Management
# 38  IST714    M001  21270      3.0              Cloud Architecture
# 35  IST363    M002  20330      3.0   Advanced Front End Web Design
#
#       Instructor(s)               Time  Day                   Room(s)
# 26       Jeff Rubin    2:55pm - 3:50pm    F            Hinds Hall 010
# 49  Jill Hurst-Wahl  12:00am - 12:00am  NaN                    Online
# 35              NaN   9:30am - 12:15pm    W            Hinds Hall 021
# 38   Lee W McKnight    5:15pm - 8:05pm    W            Hinds Hall 018
# 35  Jonathan Backus    3:45pm - 5:05pm   MW  Shaffer Art Building 121

# %%
classes[classes['Credits'] == 3]
#how do panda filter index
# Out:
#     Course Section  Class  Credits                              Title  \
# 0   IST736    M001  20698      3.0                        Text Mining
# 1   IST736    M002  21140      3.0                        Text Mining
# 2   IST747    M001  16981      3.0     Complex Issues in IT Proj Mgmt
# 3   IST755    M001  21028      3.0      Strategic Mgmt/Info Resources
# 4   IST777    M001  20348      3.0         Statistical Methods in IST
# 8   IST830    M001  21001      3.0     Theories of (Digital) Technolo
# 14  IST972    M001  16894      3.0             School Media Practicum
# 0   GET239    M003  16977      3.0            Enterprise Technologies
# 1   GET305    M001  16984      3.0      Globalization, Culture and IT
# 3   IDS401    M001  16945      3.0               What's the Big Idea?
# 4   IDS402    M001  20357      3.0                       Idea2Startup
# 6   IDS460    M001  21293      3.0                     StartUp Dublin
# 7   IDS460    M002  21381      3.0                       Peak to Peak
# 8   IDS660    M001  21294      3.0                     StartUp Dublin
# 9   IDS660    M002  21515      3.0                       Peak to Peak
# 19  IST195    M001  16906      3.0           Information Technologies
# 20  IST195    M002  16907      3.0      LAB: Information Technologies
# 21  IST195    M003  16908      3.0      LAB: Information Technologies
# 22  IST195    M004  16909      3.0      LAB: Information Technologies
# 23  IST195    M005  16910      3.0      LAB: Information Technologies
# 24  IST195    M006  16911      3.0      LAB: Information Technologies
# 25  IST195    M007  16912      3.0      LAB: Information Technologies
# 26  IST195    M008  16913      3.0      LAB: Information Technologies
# 27  IST195    M010  16960      3.0           Information Technologies
# 28  IST233    M001  16899      3.0       Intro to Computer Networking
# 29  IST233    M002  16931      3.0  LAB: Intro to Computer Networking
# 30  IST233    M003  16932      3.0  LAB: Intro to Computer Networking
# 31  IST233    M004  16933      3.0  LAB: Intro to Computer Networking
# 32  IST233    M005  16936      3.0  LAB: Intro to Computer Networking
# 33  IST233    M006  17050      3.0  LAB: Intro to Computer Networking
# ..     ...     ...    ...      ...                                ...
# 24  IST664    M002  20725      3.0        Natural Language Processing
# 25  IST668    M400  16942      3.0      Litrcy Through Schl Libraries
# 26  IST678    M001  16986      3.0        Comm for Info Professionals
# 27  IST678    M002  16987      3.0        Comm for Info Professionals
# 28  IST687    M001  16990      3.0       Introduction to Data Science
# 29  IST687    M002  17019      3.0  LAB: Introduction to Data Science
# 30  IST687    M003  17020      3.0  LAB: Introduction to Data Science
# 31  IST687    M004  17021      3.0  LAB: Introduction to Data Science
# 32  IST687    M005  17069      3.0  LAB: Introduction to Data Science
# 33  IST687    M006  17070      3.0  LAB: Introduction to Data Science
# 34  IST687    M007  17139      3.0  LAB: Introduction to Data Science
# 35  IST687    M008  21341      3.0  LAB: Introduction to Data Science
# 36  IST704    M001  21324      3.0              Applied Info Security
# 37  IST711    M800  16937      3.0                       e-Government
# 38  IST714    M001  21270      3.0                 Cloud Architecture
# 39  IST718    M002  17034      3.0     Advanced Information Analytics
# 40  IST718    M003  20891      3.0     Advanced Information Analytics
# 41  IST719    M001  16991      3.0          Information Visualization
# 42  IST719    M002  20704      3.0          Information Visualization
# 46  IST722    M001  17117      3.0                     Data Warehouse
# 47  IST726    M800  16916      3.0            Enterprise Architecture
# 48  IST728    M001  16930      3.0        Information Security Policy
# 49  IST735    M800  21320      3.0     Copyright for Information Prof
# 0   IST736    M001  20698      3.0                        Text Mining
# 1   IST736    M002  21140      3.0                        Text Mining
# 2   IST747    M001  16981      3.0     Complex Issues in IT Proj Mgmt
# 3   IST755    M001  21028      3.0      Strategic Mgmt/Info Resources
# 4   IST777    M001  20348      3.0         Statistical Methods in IST
# 8   IST830    M001  21001      3.0     Theories of (Digital) Technolo
# 14  IST972    M001  16894      3.0             School Media Practicum
#
#               Instructor(s)               Time   Day  \
# 0                    Bei Yu   9:30am - 12:15pm     W
# 1                    Bei Yu    2:15pm - 5:05pm     W
# 2        JoAnne Wallingford    5:15pm - 8:00pm     M
# 3          Murali Venkatesh   9:30am - 12:15pm    Th
# 4            Kevin Crowston   9:30am - 12:15pm     M
# 8              Bryan Semaan   9:30am - 12:15pm     W
# 14       Patricia C Vilello    1:00am - 1:00am   NaN
# 0           P Douglas Taber  11:00am - 12:20pm  TuTh
# 1           Ehsan Sabaghian   9:30am - 10:50am  TuTh
# 3      Marcene S. Sonneborn    2:00pm - 3:20pm  TuTh
# 4       Michael A D'Eredita    5:15pm - 8:05pm     M
# 6         John DuRoss Liddy  12:00am - 12:00am   NaN
# 7         John DuRoss Liddy  12:00am - 12:00am   NaN
# 8         John DuRoss Liddy  12:00am - 12:00am   NaN
# 9         John DuRoss Liddy  12:00am - 12:00am   NaN
# 19               Jeff Rubin  10:35am - 11:30am    MW
# 20               Jeff Rubin    8:25am - 9:20am     F
# 21               Jeff Rubin   9:30am - 10:25am     F
# 22               Jeff Rubin  10:35am - 11:30am     F
# 23               Jeff Rubin  11:40am - 12:35pm     F
# 24               Jeff Rubin   12:45pm - 1:40pm     F
# 25               Jeff Rubin    1:50pm - 2:45pm     F
# 26               Jeff Rubin    2:55pm - 3:50pm     F
# 27         A Randall Wenner    5:00pm - 7:50pm    Th
# 28            David J Molta   12:30pm - 1:50pm  TuTh
# 29            David J Molta   9:30am - 10:25am     F
# 30            David J Molta  11:40am - 12:35pm     F
# 31            David J Molta   12:45pm - 1:40pm     F
# 32            David J Molta    1:50pm - 2:50pm     F
# 33            David J Molta    3:00pm - 3:55pm     F
# ..                      ...                ...   ...
# 24                  Lu Xiao    2:15pm - 5:05pm     M
# 25         Sara Kelly Johns    7:00pm - 8:30pm     W
# 26                      NaN    2:15pm - 3:35pm    MW
# 27       Laura D. Lisnyczyj   12:45pm - 2:05pm    MW
# 28            Jeffrey Saltz   9:30am - 10:50am    Th
# 29      Erik Scott Anderson   12:30pm - 1:50pm    Th
# 30      Erik Scott Anderson    2:00pm - 3:20pm    Th
# 31      Erik Scott Anderson    3:30pm - 4:50pm    Th
# 32            Gary E Krudys    5:15pm - 6:35pm     M
# 33            Gary E Krudys    6:45pm - 8:05pm     M
# 34                      NaN   12:30pm - 1:50pm    Th
# 35            Jeffrey Saltz  11:00am - 12:20pm    Th
# 36  Benson Mathews Poikayil   9:30am - 12:15pm    Th
# 37            Amit Magdieli  12:00am - 12:00am   NaN
# 38           Lee W McKnight    5:15pm - 8:05pm     W
# 39          Daniel E. Acuna   9:30am - 12:15pm     M
# 40          Daniel E. Acuna   9:30am - 12:15pm    Tu
# 41             Jeff Hemsley   9:30am - 12:15pm    Tu
# 42             Jeff Hemsley   9:30am - 12:15pm     W
# 46          P Douglas Taber    5:00pm - 7:45pm    Th
# 47          Scott A Bernard  12:00am - 12:00am   NaN
# 48           Lee W McKnight    1:00pm - 2:15pm    MW
# 49          Jill Hurst-Wahl  12:00am - 12:00am   NaN
# 0                    Bei Yu   9:30am - 12:15pm     W
# 1                    Bei Yu    2:15pm - 5:05pm     W
# 2        JoAnne Wallingford    5:15pm - 8:00pm     M
# 3          Murali Venkatesh   9:30am - 12:15pm    Th
# 4            Kevin Crowston   9:30am - 12:15pm     M
# 8              Bryan Semaan   9:30am - 12:15pm     W
# 14       Patricia C Vilello    1:00am - 1:00am   NaN
#
#                            Room(s)
# 0                   Hinds Hall 013
# 1                   Hinds Hall 013
# 2                   Hinds Hall 021
# 3                   Hinds Hall 117
# 4                   Hinds Hall 120
# 8                   Hinds Hall 120
# 14                             NaN
# 0                   Hinds Hall 013
# 1                   Hinds Hall 111
# 3                   Hinds Hall 021
# 4                   Hinds Hall 117
# 6                           Online
# 7                           Online
# 8                           Online
# 9                           Online
# 19                Grant Auditorium
# 20                  Hinds Hall 010
# 21                  Hinds Hall 010
# 22                  Hinds Hall 010
# 23                  Hinds Hall 010
# 24                  Hinds Hall 010
# 25                  Hinds Hall 010
# 26                  Hinds Hall 010
# 27  Hinds Hall 010  Newhouse 3 250
# 28           Hall of Languages 207
# 29                  Hinds Hall 027
# 30                  Hinds Hall 027
# 31                  Hinds Hall 027
# 32                  Hinds Hall 027
# 33                  Hinds Hall 027
# ..                             ...
# 24                  Hinds Hall 010
# 25                          Online
# 26                  Hinds Hall 121
# 27                  Hinds Hall 121
# 28                Grant Auditorium
# 29                  Hinds Hall 117
# 30                  Hinds Hall 117
# 31                  Hinds Hall 018
# 32           Hall of Languages 205
# 33           Hall of Languages 102
# 34                  Hinds Hall 111
# 35                  Hinds Hall 011
# 36                  Hinds Hall 027
# 37                          Online
# 38                  Hinds Hall 018
# 39                  Hinds Hall 011
# 40                  Hinds Hall 011
# 41                  Hinds Hall 010
# 42                  Hinds Hall 010
# 46           Hall of Languages 214
# 47                          Online
# 48  360 DINEEN HALL 950 IRVING AVE
# 49                          Online
# 0                   Hinds Hall 013
# 1                   Hinds Hall 013
# 2                   Hinds Hall 021
# 3                   Hinds Hall 117
# 4                   Hinds Hall 120
# 8                   Hinds Hall 120
# 14                             NaN
#
# [197 rows x 9 columns]

# %%
def engineer_grad_ugrad(classes):
    classes['CourseNum'] = classes['Course'].str[3:]
    classes['Type'] = 'None'
    classes['Type'][classes['CourseNum'].astype(int)>= 500] = 'G' #retrieve that course number as type integer
    classes['Type'][classes['CourseNum'].astype(int)<500] = 'U'
    return classes

# %%
classes = get_classes_from_website()
classes = engineer_grad_ugrad(classes)

# %%
ugrad = classes[classes['Type'] == 'U']
friday = ugrad[ugrad['IST'].str.find("")>=0]
friday
# Out:
#     Course Section  Class  Credits                           Title  \
# 4   IDS402    M001  20357      3.0                    Idea2Startup
# 20  IST195    M002  16907      3.0   LAB: Information Technologies
# 45  IST263    M002  16939      3.0      Intro to Front-End Web Dev
# 46  IST263    M004  17014      3.0      Intro to Front-End Web Dev
# 0   IST300    M004  21334      3.0        Enterprise Data Analysis
# 13  IST344    M012  16988      3.0   Info Reporting & Presentation
# 14  IST344    M001  17039      3.0   Info Reporting & Presentation
# 15  IST345    M002  16914      3.0  Managing Info Systems Projects
# 17  IST345    M001  16959      3.0  Managing Info Systems Projects
# 20  IST346    M003  16926      3.0   Info Tech Mgmt&Administration
# 23  IST352    M001  16919      3.0   Info Analysis of Org. Systems
# 31  IST359    M006  16989      3.0   Intro to Data Base Mgmt Systs
# 33  IST359    M002  17128      3.0   Intro to Data Base Mgmt Systs
# 39  IST400    M004  16985      3.0             Innovations Lecture
# 40  IST400    M001  17083      3.0               Block Chain Mgmt.
# 47  IST447    M001  16980      3.0  Complex Issues in IT Proj Mgmt
#
#              Instructor(s)             Time   Day         Room(s) CourseNum  \
# 4      Michael A D'Eredita  5:15pm - 8:05pm     M  Hinds Hall 117       402
# 20              Jeff Rubin  8:25am - 9:20am     F  Hinds Hall 010       195
# 45  Christian A Kirkegaard  8:00am - 9:20am  TuTh  Hinds Hall 011       263
# 46                     NaN  5:15pm - 8:00pm     W  Hinds Hall 011       263
# 0            Gary Friedman  5:15pm - 8:05pm     M  Hinds Hall 010       300
# 13    Christopher Perrello  8:00am - 9:20am  TuTh  Hinds Hall 021       344
# 14            Bruce Kingma  8:00am - 9:20am  TuTh  Hinds Hall 018       344
# 15            Daniel Cohen  8:00am - 9:20am  TuTh  Hinds Hall 117       345
# 17       Mark Andrew Borte  5:15pm - 8:05pm    Tu  Hinds Hall 111       345
# 20             Ryan Elstad  5:15pm - 8:00pm     W  Hinds Hall 010       346
# 23         P Douglas Taber  5:15pm - 8:00pm     M  Hinds Hall 111       352
# 31         Blythe Scherrer  5:15pm - 8:00pm     W  Hinds Hall 013       359
# 33         Blythe Scherrer  8:00am - 9:20am    MW  Hinds Hall 027       359
# 39          Carl J Schramm  5:15pm - 8:00pm     W  Hinds Hall 120       400
# 40        Phil Evangelista  5:15pm - 8:00pm     W  Bowne Hall 105       400
# 47      JoAnne Wallingford  5:15pm - 8:00pm     M  Hinds Hall 021       447
#
#    Type
# 4     U
# 20    U
# 45    U
# 46    U
# 0     U
# 13    U
# 14    U
# 15    U
# 17    U
# 20    U
# 23    U
# 31    U
# 33    U
# 39    U
# 40    U
# 47    U

# %%
# just figure out how to get the data
website = 'https://ischool.syr.edu/classes/'
data = pd.read_html(website)
data[0]
# Out:
#     Course Section  Class  Credits                           Title  \
# 0   GET471    M801  70843      1.0                  GET Internship
# 1   IST387    M001  72570      3.0   Intro to Applied Data Science
# 2   IST471    M002  70840      1.0  Internship in Info Mgmt & Tech
# 3   IST471    M003  70849      1.0  Internship in Info Mgmt & Tech
# 4   IST471    M001  70899      1.0  Internship in Info Mgmt & Tech
# 5   IST472    M800  70865      1.0   Coop Educ in Info Mgmt & Tech
# 6   IST472    M801  70866      1.0   Coop Educ in Info Mgmt & Tech
# 7   IST511    M401  70875      3.0    Intro to Library & Info Prof
# 8   IST511    M402  72400      3.0    Intro to Library & Info Prof
# 9   IST564    M400  72344      3.0   Lib Svces to Students w/Disab
# 10  IST564    M401  72399      3.0   Lib Svces to Students w/Disab
# 11  IST565    M001  70856      3.0                     Data Mining
# 12  IST565    M400  72439      3.0                     Data Mining
# 13  IST565    M401  72440      3.0                     Data Mining
# 14  IST565    M402  72441      3.0                     Data Mining
# 15  IST565    M403  72442      3.0                     Data Mining
# 16  IST600    M200  70869      3.0  WISE: Informal Learning Spaces
# 17  IST600    M201  70870      1.0            WISE: Graphic Novels
# 18  IST600    M203  70871      3.0  WISE: Proj Mgmt: Strat/Applica
# 19  IST600    M001  72173      3.0    Adv TopicsUser Experience UX
# 20  IST600    M202  72421      2.0  WISE: Soc Justice in Youth Lit
# 21  IST602    M001  70853      3.0               Digital Forensics
# 22  IST605    M400  72401      3.0  Reference& Info Literacy Svces
# 23  IST605    M402  72537      3.0  Reference& Info Literacy Svces
# 24  IST612    M400  72402      3.0  Youth Svce inLibrary Info Ctrs
# 25  IST614    M400  70879      3.0  Mngmt Prncpls for Info Profess
# 26  IST614    M401  70880      3.0  Mngmt Prncpls for Info Profess
# 27  IST614    M402  72406      3.0  Mngmt Prncpls for Info Profess
# 28  IST616    M400  70863      3.0    Info Rsces: Organiz & Access
# 29  IST616    M401  70881      3.0    Info Rsces: Organiz & Access
# 30  IST618    M400  70864      3.0              Information Policy
# 31  IST618    M401  70883      3.0              Information Policy
# 32  IST618    M402  72403      3.0              Information Policy
# 33  IST621    M400  70884      3.0      Intro to Information Mgmt.
# 34  IST623    M400  70885      3.0   Intro to Information Security
# 35  IST625    M001  70857      3.0      Enterprise Risk Management
# 36  IST625    M400  72475      3.0      Enterprise Risk Management
# 37  IST636    M400  72407      3.0    Leading Issues/Info Security
# 38  IST639    M001  72325      3.0         Enterprise Technologies
# 39  IST645    M400  70887      3.0  Managing Info Systems Projects
# 40  IST652    M400  72408      3.0     Scripting for Data Analysis
# 41  IST652    M401  72409      3.0     Scripting for Data Analysis
# 42  IST654    M400  70889      3.0    Information Systems Analysis
# 43  IST654    M001  72174      3.0    Information Systems Analysis
# 44  IST659    M400  70892      3.0   Data Admin Concepts & Db Mgmt
# 45  IST659    M401  72410      3.0   Data Admin Concepts & Db Mgmt
# 46  IST659    M402  72411      3.0   Data Admin Concepts & Db Mgmt
# 47  IST659    M403  72443      3.0   Data Admin Concepts & Db Mgmt
# 48  IST662    M401  72405      3.0   Instr Strgt & Tech/Info Profs
# 49  IST662    M400  72561      3.0   Instr Strgt & Tech/Info Profs
#
#                   Instructor(s)               Time        Day         Room(s)
# 0                           NaN  12:00am - 12:00am        NaN             NaN
# 1                 Jeffrey Saltz    9:00am - 5:00pm    MTuWThF  Hinds Hall 018
# 2            Susan Monica Bonzi    1:00am - 1:00am        NaN             NaN
# 3            Susan Monica Bonzi  12:00am - 12:00am        NaN             NaN
# 4            Susan Monica Bonzi  12:00am - 12:00am        NaN             NaN
# 5                           NaN  12:00am - 12:00am        NaN             NaN
# 6                           NaN  12:00am - 12:00am        NaN             NaN
# 7               DeAnna R Miller    7:00pm - 8:30pm          W          Online
# 8              Alison J Johnson   9:00pm - 10:30pm          M          Online
# 9             William N. Myhill    7:00pm - 8:30pm          M          Online
# 10            William N. Myhill    7:00pm - 8:30pm         Th          Online
# 11                       Bei Yu    9:00am - 5:00pm    MTuWThF  Hinds Hall 013
# 12                     Ying Lin   9:00pm - 10:30pm         Th          Online
# 13                     Ying Lin   9:00pm - 10:30pm         Su          Online
# 14              Dr. Ami M Gates    1:00pm - 2:30pm         Su          Online
# 15              Dr. Ami M Gates    3:00pm - 4:30pm         Su          Online
# 16               Blythe Bennett  12:00am - 12:00am        NaN          Online
# 17               Blythe Bennett  12:00am - 12:00am        NaN          Online
# 18               Blythe Bennett  12:00am - 12:00am        NaN          Online
# 19                   Ping Zhang    9:00am - 5:00pm    MTuWThF  Hinds Hall 111
# 20               Blythe Bennett    7:00pm - 9:00pm          W          Online
# 21              Mark M. Pollitt    9:00am - 5:00pm  MTuWThFSa  Hinds Hall 027
# 22            Rebecca K. Miller    7:00pm - 8:30pm          W          Online
# 23            Rebecca K. Miller   9:00pm - 10:30pm         Tu          Online
# 24                Kori M Gerbig    7:00pm - 8:30pm          W          Online
# 25         Dr. John P. Stinnett    7:00pm - 8:30pm          M          Online
# 26         Dr. John P. Stinnett   9:00pm - 10:30pm          M          Online
# 27         Dr. John P. Stinnett   9:00pm - 10:30pm         Tu          Online
# 28               Arden Kirkland    7:00pm - 8:30pm         Th          Online
# 29               Arden Kirkland    7:00pm - 8:30pm         Tu          Online
# 30     Martha A. Garcia-Murillo    7:00pm - 8:30pm         Tu          Online
# 31     Martha A. Garcia-Murillo    7:00pm - 8:30pm          W          Online
# 32               Lauren Britton    7:00pm - 8:30pm          M          Online
# 33  Angela Usha Ramnarine-Rieks   9:00pm - 10:30pm         Tu          Online
# 34                 Joon S. Park    5:00pm - 6:30pm          W          Online
# 35               James Enwright    9:00am - 5:00pm    MTuWThF  Hinds Hall 018
# 36               Michael Larche    7:00pm - 8:30pm          M          Online
# 37                 Joon S. Park    7:00pm - 8:30pm          W          Online
# 38              P Douglas Taber    9:00am - 5:00pm    MTuWThF  Hinds Hall 010
# 39            Robert A Emborski    7:00pm - 8:30pm         Th          Online
# 40                          NaN    5:00pm - 6:30pm         Th          Online
# 41                          NaN    5:00pm - 6:30pm          W          Online
# 42                 Gregory Zink    7:00pm - 8:30pm         Tu          Online
# 43                   Ping Zhang    9:00am - 5:00pm    MTuWThF  Hinds Hall 111
# 44            Dr. Gregory Block    4:00pm - 5:30pm         Su          Online
# 45            Chad Aaron Harper    7:00pm - 8:30pm          M          Online
# 46            Chad Aaron Harper   9:00pm - 10:30pm          M          Online
# 47               Ralph T Reilly    2:00pm - 3:30pm         Su          Online
# 48                Megan Oakleaf   9:00pm - 10:30pm          W          Online
# 49                Megan Oakleaf   9:00pm - 10:00pm         Tu          Online

# %%
# let's generate links to the other pages
website = 'https://ischool.syr.edu/classes/?page='
for i in range(1,6):
    link = website + str(i)
    print(link)
# Out:
# https://ischool.syr.edu/classes/?page=1
# https://ischool.syr.edu/classes/?page=2
# https://ischool.syr.edu/classes/?page=3
# https://ischool.syr.edu/classes/?page=4
# https://ischool.syr.edu/classes/?page=5

# %%
# let's read them all and append them to a single data frame

website = 'https://ischool.syr.edu/classes/?page='
classes = pd.DataFrame() #  (columns = ['Course','Section','ClassNo','Credits','Title','Instructor','Time','Days','Room'])

for i in range(1,6):
    link = website + str(i)
    data = pd.read_html(website  + str(i))    
    classes = classes.append(data[0], ignore_index=True)
    
classes.sample(5)
# Out:
#      Course Section  Class  Credits                           Title  \
# 53   IST687    M400  70893      3.0            Applied Data Science
# 172  IST972    M800  70841      3.0          School Media Practicum
# 85   IST687    M401  72444      3.0    Introduction to Data Science
# 173  IST999    M800  70842      1.0                    Dissertation
# 22   IST605    M400  72401      3.0  Reference& Info Literacy Svces
#
#           Instructor(s)               Time  Day Room(s)
# 53                  NaN    7:00pm - 8:30pm    M  Online
# 172  Patricia C Vilello    1:00am - 1:00am  NaN     NaN
# 85      Mohammed A Syed   9:00pm - 10:30pm    M  Online
# 173                 NaN  12:00am - 12:00am  NaN     NaN
# 22    Rebecca K. Miller    7:00pm - 8:30pm    W  Online

# %%
## let's set the columns

website = 'https://ischool.syr.edu/classes/?page='
classes = pd.DataFrame() 

for i in range(1,6):
    link = website + str(i)
    data = pd.read_html(website  + str(i))    
    classes = classes.append(data[0], ignore_index=True)
    
classes.columns = ['Course','Section','ClassNo','Credits','Title','Instructor','Time','Days','Room']

classes.sample(5)
# Out:
#      Course Section  ClassNo  Credits                         Title  \
# 88   IST687    M404    72476      3.0  Introduction to Data Science
# 15   IST565    M403    72442      3.0                   Data Mining
# 74   IST971    M401    72478      1.0    Internship in Info Studies
# 164  IST971    M802    70847      1.0    Internship in Info Studies
# 42   IST654    M400    70889      3.0  Information Systems Analysis
#
#              Instructor               Time Days    Room
# 88      Mohammed A Syed   9:00pm - 10:30pm   Th  Online
# 15      Dr. Ami M Gates    3:00pm - 4:30pm   Su  Online
# 74   Susan Monica Bonzi  12:00am - 12:00am  NaN     NaN
# 164            Jian Qin  12:00am - 12:00am  NaN     NaN
# 42         Gregory Zink    7:00pm - 8:30pm   Tu  Online

# %%
## this is good stuff. Let's make a function out of it for simplicity

def get_ischool_classes():
    website = 'https://ischool.syr.edu/classes/?page='
    classes = pd.DataFrame() 

    for i in range(1,6):
        link = website + str(i)
        data = pd.read_html(website  + str(i))    
        classes = classes.append(data[0], ignore_index=True)
    
    classes.columns = ['Course','Section','ClassNo','Credits','Title','Instructor','Time','Days','Room']

    return classes

# main program 
classes = get_ischool_classes()

# %%
# undergrad classes are 0-499, grad classes are 500 and up but we don't have course numbers!!!! So we must engineer them.

classes['Course'].str[0:3].sample(5)
classes['Course'].str[3:].sample(5)
# Out:
# 2      471
# 162    755
# 106    971
# 122    718
# 116    687
# Name: Course, dtype: object

# %%
# make the subject and number columns
classes['Subject'] = classes['Course'].str[0:3]
classes['Number'] = classes['Course'].str[3:]
classes.sample(5)
# Out:
#      Course Section  ClassNo  Credits                           Title  \
# 94   IST720    M802    72446      2.0    Topics in Library Leadership
# 17   IST600    M201    70870      1.0            WISE: Graphic Novels
# 160  IST736    M400    72413      3.0                     Text Mining
# 4    IST471    M001    70899      1.0  Internship in Info Mgmt & Tech
# 31   IST618    M401    70883      3.0              Information Policy
#
#                    Instructor               Time    Days  \
# 94    Rebecca Shaffer Mannion   12:00am - 1:00pm  MTuWTh
# 17             Blythe Bennett  12:00am - 12:00am     NaN
# 160                    Bei Yu    5:00pm - 6:30pm      Tu
# 4          Susan Monica Bonzi  12:00am - 12:00am     NaN
# 31   Martha A. Garcia-Murillo    7:00pm - 8:30pm       W
#
#                        Room Subject Number
# 94   Hinds Hall 121  Online     IST    720
# 17                   Online     IST    600
# 160                  Online     IST    736
# 4                       NaN     IST    471
# 31                   Online     IST    618

# %%
# and finally we can create the column we need!
classes['Type'] = ''
classes['Type'][classes['Number'] < '500'] = 'UGrad'
classes['Type'][classes['Number'] >= '500'] = 'Grad'

classes.sample(5)
# Out:
#      Course Section  ClassNo  Credits                           Title  \
# 98   IST736    M400    72413      3.0                     Text Mining
# 74   IST971    M401    72478      1.0      Internship in Info Studies
# 0    GET471    M801    70843      1.0                  GET Internship
# 20   IST600    M202    72421      2.0  WISE: Soc Justice in Youth Lit
# 172  IST972    M800    70841      3.0          School Media Practicum
#
#              Instructor               Time Days    Room Subject Number   Type
# 98               Bei Yu    5:00pm - 6:30pm   Tu  Online     IST    736   Grad
# 74   Susan Monica Bonzi  12:00am - 12:00am  NaN     NaN     IST    971   Grad
# 0                   NaN  12:00am - 12:00am  NaN     NaN     GET    471  UGrad
# 20       Blythe Bennett    7:00pm - 9:00pm    W  Online     IST    600   Grad
# 172  Patricia C Vilello    1:00am - 1:00am  NaN     NaN     IST    972   Grad

# %%
# the entire program to retrieve the data and setup the columns looks like this:

# main program 
classes = get_ischool_classes()
classes['Subject'] = classes['Course'].str[0:3]
classes['Number'] = classes['Course'].str[3:]
classes['Type'] = ''
classes['Type'][classes['Number'] < '500'] = 'UGrad'
classes['Type'][classes['Number'] >= '500'] = 'Grad'

# %%
# let's fins the number of grad / undergrad courses
classes['Type'].value_counts()

# more grad classes than undergrad
# Out:
# Grad     167
# UGrad      7
# Name: Type, dtype: int64

# %%
# how many undergrad classes on a Friday?
friday = classes[ (classes['Type'] == 'UGrad') & (classes['Days'].str.find('F')>=0 ) ]
friday
# Out:
#    Course Section  ClassNo  Credits                          Title  \
# 1  IST387    M001    72570      3.0  Intro to Applied Data Science
#
#       Instructor             Time     Days            Room Subject Number  \
# 1  Jeffrey Saltz  9:00am - 5:00pm  MTuWThF  Hinds Hall 018     IST    387
#
#     Type
# 1  UGrad

# %%
# let's get rid of those pesky LAB sections!!!
# how many undergrad classes on a Friday?
friday_no_lab = friday[ ~friday['Title'].str.startswith('LAB:')]
friday_no_lab
# Out:
#    Course Section  ClassNo  Credits                          Title  \
# 1  IST387    M001    72570      3.0  Intro to Applied Data Science
#
#       Instructor             Time     Days            Room Subject Number  \
# 1  Jeffrey Saltz  9:00am - 5:00pm  MTuWThF  Hinds Hall 018     IST    387
#
#     Type
# 1  UGrad

# %%
# Looking for more classes to avoid? How about 8AM classes?
eight_am = classes[ classes['Time'].str.startswith('8:00am')]
eight_am
# Out:
# Empty DataFrame
# Columns: [Course, Section, ClassNo, Credits, Title, Instructor, Time, Days, Room, Subject, Number, Type]
# Index: []
